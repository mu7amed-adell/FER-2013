# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, Input, AveragePooling2D, LSTM, Reshape,GlobalAveragePooling2D
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau ,TensorBoard
from keras import regularizers
from keras.applications.vgg16 import VGG16

from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import cv2
from keras.models import load_model
from keras_preprocessing.image import load_img, img_to_array, ImageDataGenerator

# %%
class_dic = {0:"Angry", 1:"Disgust", 2:"Fear", 3:"Happy", 4:"Sad", 5:"Surprise", 6:"Neutral"}

# %%
# Preprocess all train images
train_data_gen = ImageDataGenerator(rescale=1./255)

train_generator = train_data_gen.flow_from_directory(
        'D:/Everything/Development Setup/GP/FER-2013/train',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.

# %%
# Preprocess all test images
validation_data_gen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_data_gen.flow_from_directory(
        'D:/Everything/Development Setup/GP/FER-2013/test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 7178 images belonging to 7 classes.

# %%
from collections import Counter
train_counter = Counter(train_generator.classes)
val_counter = Counter(validation_generator.classes)

print(train_counter.items())
print(val_counter.items())
# Out:
# dict_items([(0, 3995), (1, 436), (2, 4097), (3, 7215), (4, 4965), (5, 4830), (6, 3171)])
# dict_items([(0, 958), (1, 111), (2, 1024), (3, 1774), (4, 1233), (5, 1247), (6, 831)])

# %% [markdown]
# ### Model Architecture

# %%
def Cnn_Lstm_model():

    model = Sequential([

    Input((48, 48, 1)),
    
    Conv2D(32, kernel_size=(3,3), strides=(1,1), padding='valid'),
    BatchNormalization(axis=3),
    Activation('relu'),
    
    Conv2D(64, (3,3), strides=(1,1), padding = 'same'),
    BatchNormalization(axis=3),
    Activation('relu'),
    MaxPooling2D((2,2)),
    Dropout(0.1),

    Conv2D(64, (3,3), strides=(1,1), padding = 'valid'),
    BatchNormalization(axis=3),
    Activation('relu'),
    
    Conv2D(128, (3,3), strides=(1,1), padding = 'same'),
    BatchNormalization(axis=3),
    Activation('relu'),
    MaxPooling2D((2,2)),
    Dropout(0.1),

    Conv2D(128, (3,3), strides=(1,1), padding = 'valid'),
    BatchNormalization(axis=3),
    Activation('relu'),
    MaxPooling2D((2,2)),
    
    Reshape((-1,128)),
    (LSTM(128)),
    Dropout(0.3),

    (Reshape((-1,64))),
    LSTM(64),
    
    Dense(200, activation='relu'),
    Dropout(0.3),

    Dense(7, activation = 'softmax')
    
    ])

    keras.utils.plot_model(model, to_file = "CNN_LSTM_model.png", show_shapes = True, show_dtype = True)

    model.summary()
    return model

# %%
lr_reduce = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.1, 
    patience=3, 
    verbose=1
)

Earlystop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    verbose =1,
)

TensBoard = TensorBoard(
    log_dir = 'logs-RegAug'
)

checkpoint = ModelCheckpoint(
    filepath = 'RegAug.h5',
    verbose = 1,
    save_best_only = True
)

# %%
model = Cnn_Lstm_model()
epochs = 100
adam = keras.optimizers.Adam(learning_rate=0.002)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  batch_normalization (BatchN  (None, 46, 46, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 46, 46, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 46, 46, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 46, 46, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 64)       0
#  )
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 21, 21, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 21, 21, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 21, 21, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 21, 21, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  reshape (Reshape)           (None, 16, 128)           0
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  reshape_1 (Reshape)         (None, 2, 64)             0
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 200)               13000
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_1 (Dense)             (None, 7)                 1407
#
# =================================================================
# Total params: 457,863
# Trainable params: 457,031
# Non-trainable params: 832
# _________________________________________________________________

# %%
# Train the neural network/model
history = model.fit(
        train_generator,
        epochs = 100,
        validation_data = validation_generator,
        callbacks= [lr_reduce, Earlystop, TensBoard, checkpoint],
)
# Out:
# Epoch 1/100
# 449/449 [==============================] - ETA: 0s - loss: 1.5528 - accuracy: 0.3822
# Epoch 1: val_loss improved from inf to 1.68048, saving model to AugW_weightedClass.h5
# 449/449 [==============================] - 342s 726ms/step - loss: 1.5528 - accuracy: 0.3822 - val_loss: 1.6805 - val_accuracy: 0.3514 - lr: 0.0020
# Epoch 2/100
# 449/449 [==============================] - ETA: 0s - loss: 1.3516 - accuracy: 0.4794
# Epoch 2: val_loss improved from 1.68048 to 1.39392, saving model to AugW_weightedClass.h5
# 449/449 [==============================] - 501s 1s/step - loss: 1.3516 - accuracy: 0.4794 - val_loss: 1.3939 - val_accuracy: 0.4511 - lr: 0.0020
# Epoch 3/100
# 449/449 [==============================] - ETA: 0s - loss: 1.2668 - accuracy: 0.5097
# Epoch 3: val_loss improved from 1.39392 to 1.25414, saving model to AugW_weightedClass.h5
# 449/449 [==============================] - 489s 1s/step - loss: 1.2668 - accuracy: 0.5097 - val_loss: 1.2541 - val_accuracy: 0.5160 - lr: 0.0020
# Epoch 4/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1982 - accuracy: 0.5425
# Epoch 4: val_loss did not improve from 1.25414
# 449/449 [==============================] - 494s 1s/step - loss: 1.1982 - accuracy: 0.5425 - val_loss: 1.2542 - val_accuracy: 0.5155 - lr: 0.0020
# Epoch 5/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1410 - accuracy: 0.5635
# Epoch 5: val_loss improved from 1.25414 to 1.16356, saving model to AugW_weightedClass.h5
# 449/449 [==============================] - 498s 1s/step - loss: 1.1410 - accuracy: 0.5635 - val_loss: 1.1636 - val_accuracy: 0.5522 - lr: 0.0020
# Epoch 6/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0858 - accuracy: 0.5895
# Epoch 6: val_loss did not improve from 1.16356
# 449/449 [==============================] - 506s 1s/step - loss: 1.0858 - accuracy: 0.5895 - val_loss: 1.1922 - val_accuracy: 0.5439 - lr: 0.0020
# Epoch 7/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0372 - accuracy: 0.6077
# Epoch 7: val_loss did not improve from 1.16356
# 449/449 [==============================] - 517s 1s/step - loss: 1.0372 - accuracy: 0.6077 - val_loss: 1.2722 - val_accuracy: 0.5249 - lr: 0.0020
# Epoch 8/100
# 449/449 [==============================] - ETA: 0s - loss: 0.9946 - accuracy: 0.6271
# Epoch 8: val_loss improved from 1.16356 to 1.14895, saving model to AugW_weightedClass.h5
# 449/449 [==============================] - 487s 1s/step - loss: 0.9946 - accuracy: 0.6271 - val_loss: 1.1490 - val_accuracy: 0.5730 - lr: 0.0020
# Epoch 9/100
# 449/449 [==============================] - ETA: 0s - loss: 0.9421 - accuracy: 0.6451
# Epoch 9: val_loss did not improve from 1.14895
# 449/449 [==============================] - 543s 1s/step - loss: 0.9421 - accuracy: 0.6451 - val_loss: 1.2112 - val_accuracy: 0.5575 - lr: 0.0020
# Epoch 10/100
# 449/449 [==============================] - ETA: 0s - loss: 0.8904 - accuracy: 0.6676
# Epoch 10: val_loss did not improve from 1.14895
# 449/449 [==============================] - 541s 1s/step - loss: 0.8904 - accuracy: 0.6676 - val_loss: 1.1708 - val_accuracy: 0.5772 - lr: 0.0020
# Epoch 11/100
# 449/449 [==============================] - ETA: 0s - loss: 0.8481 - accuracy: 0.6850
# Epoch 11: val_loss improved from 1.14895 to 1.14205, saving model to AugW_weightedClass.h5
# 449/449 [==============================] - 567s 1s/step - loss: 0.8481 - accuracy: 0.6850 - val_loss: 1.1420 - val_accuracy: 0.5921 - lr: 0.0020
# Epoch 12/100
# 449/449 [==============================] - ETA: 0s - loss: 0.7962 - accuracy: 0.7047
# Epoch 12: val_loss did not improve from 1.14205
# 449/449 [==============================] - 532s 1s/step - loss: 0.7962 - accuracy: 0.7047 - val_loss: 1.1494 - val_accuracy: 0.5925 - lr: 0.0020
# Epoch 13/100
# 449/449 [==============================] - ETA: 0s - loss: 0.7512 - accuracy: 0.7209
# Epoch 13: val_loss improved from 1.14205 to 1.13965, saving model to AugW_weightedClass.h5
# 449/449 [==============================] - 527s 1s/step - loss: 0.7512 - accuracy: 0.7209 - val_loss: 1.1396 - val_accuracy: 0.5996 - lr: 0.0020
# Epoch 14/100
# 449/449 [==============================] - ETA: 0s - loss: 0.7039 - accuracy: 0.7401
# Epoch 14: val_loss did not improve from 1.13965
# 449/449 [==============================] - 489s 1s/step - loss: 0.7039 - accuracy: 0.7401 - val_loss: 1.1769 - val_accuracy: 0.6077 - lr: 0.0020
# Epoch 15/100
# 449/449 [==============================] - ETA: 0s - loss: 0.6582 - accuracy: 0.7608
# Epoch 15: val_loss did not improve from 1.13965
# 449/449 [==============================] - 517s 1s/step - loss: 0.6582 - accuracy: 0.7608 - val_loss: 1.1607 - val_accuracy: 0.6069 - lr: 0.0020
# Epoch 16/100
# 449/449 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.7713
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 16: val_loss did not improve from 1.13965
# 449/449 [==============================] - 488s 1s/step - loss: 0.6248 - accuracy: 0.7713 - val_loss: 1.2682 - val_accuracy: 0.5850 - lr: 0.0020
# Epoch 17/100
# 449/449 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.8288
# Epoch 17: val_loss did not improve from 1.13965
# 449/449 [==============================] - 504s 1s/step - loss: 0.4715 - accuracy: 0.8288 - val_loss: 1.2703 - val_accuracy: 0.6289 - lr: 2.0000e-04
# Epoch 18/100
# 449/449 [==============================] - ETA: 0s - loss: 0.4188 - accuracy: 0.8500
# Epoch 18: val_loss did not improve from 1.13965
# 449/449 [==============================] - 504s 1s/step - loss: 0.4188 - accuracy: 0.8500 - val_loss: 1.3189 - val_accuracy: 0.6271 - lr: 2.0000e-04
# Epoch 18: early stopping

# %% [markdown]
# ### Accuracy & Loss plots

# %%
acc = plt.figure(figsize = (6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('FER using CNN-LSTM Reg Aug - Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
acc.savefig("ACC-Reg_Aug")
plt.show()

# %%
loss = plt.figure(figsize = (6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('FER using CNN-LSTM Reg_Aug - Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
loss.savefig("LOSS-Reg_Aug")
plt.show()

# %%
prediction = model.predict(validation_generator)
# Out:
# 113/113 [==============================] - 49s 275ms/step

# %%
loss, accuracy = model.evaluate(validation_generator, 
                                verbose=0)     

print("Accuracy of our model on validation data : ", accuracy*100, "%")
print("Accuracy of our model on validation data : ", loss)
# Out:
# Accuracy of our model on validation data :  62.70548701286316 %
# Accuracy of our model on validation data :  1.3189358711242676

# %% [markdown]
# ### Classification Report & Confusion Matrix

# %%
# Classification report
print(classification_report(validation_generator.classes, prediction.argmax(axis=1)))

# confusion matrix
c_matrix = confusion_matrix(validation_generator.classes, prediction.argmax(axis=1))
cm_display = ConfusionMatrixDisplay(confusion_matrix=c_matrix, display_labels=class_dic.values())
cm_display.plot()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.17      0.15       958
#            1       0.00      0.00      0.00       111
#            2       0.14      0.11      0.12      1024
#            3       0.25      0.24      0.25      1774
#            4       0.16      0.17      0.16      1233
#            5       0.16      0.16      0.16      1247
#            6       0.11      0.12      0.12       831
#
#     accuracy                           0.17      7178
#    macro avg       0.14      0.14      0.14      7178
# weighted avg       0.17      0.17      0.17      7178
